# %%
import os
import torch
import sys
import re
import fitz  # PyMuPDF
from PIL import Image
import cv2
from utils.general import scale_boxes

# Configuration
# Configuration
BASE_DIR = "/Users/rithwanali/Documents/auto_blueprint/Auto-Blueprints"
YOLO_DIR = os.path.join(BASE_DIR, "yolov5")  # Fixed path
IMAGE_PATH = os.path.join(BASE_DIR, "dataset/images")
PDF_PATH = os.path.join(BASE_DIR, "data_lake/blueprints/bygg/6.4 Ritningar/6.4.6 Akustik ritningar.pdf")
OUTPUT_DIR = os.path.join(BASE_DIR, "results_yolo")
MODEL_PATH = os.path.join(YOLO_DIR, "models", "yolov5l.yaml")  # Correct model path


# Window detection parameters
CONF_THRESH = 0.25  # Confidence threshold
IOU_THRESH = 0.45  # NMS IOU threshold

def setup_environment():
    """Validate paths and setup system environment"""
    required_paths = {
        "YOLOv5 directory": YOLO_DIR,
        "Image path": IMAGE_PATH,
        "PDF path": PDF_PATH,
        "Model path": MODEL_PATH
    }
    
    for name, path in required_paths.items():
        if not os.path.exists(path):
            raise FileNotFoundError(f"{name} not found at: {path}")
    
    if YOLO_DIR not in sys.path:
        sys.path.insert(0, YOLO_DIR)
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)

def detect_windows():
    """Run YOLOv5 window detection on the target image"""
    from models.experimental import attempt_load
    from utils.general import non_max_suppression, scale_coords, letterbox
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = attempt_load(MODEL_PATH, device=device)
    
    # Image preprocessing
    img0 = cv2.imread(IMAGE_PATH)
    img = letterbox(img0, new_shape=640)[0]
    img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB
    img = torch.as_tensor(img, device=device).float()
    img /= 255.0
    img = img.unsqueeze(0)
    
    # Inference
    with torch.no_grad():
        pred = model(img)[0]
    
    # Post-process
    pred = non_max_suppression(pred, CONF_THRESH, IOU_THRESH)
    
    # Process detections
    window_data = []
    for det in pred:
        if len(det):
            det[:, :4] = scale_coords(img.shape[2:], det[:, :4], img0.shape).round()
            for *xyxy, conf, cls in det:
                window_data.append({
                    "bbox": [int(x) for x in xyxy],
                    "confidence": float(conf),
                    "class": int(cls)
                })
                # Draw bounding box
                cv2.rectangle(img0, (int(xyxy[0]), int(xyxy[1])), 
                            (int(xyxy[2]), int(xyxy[3])), (0, 255, 0), 2)
    
    # Save output
    output_img = os.path.join(OUTPUT_DIR, "detected_windows.jpg")
    cv2.imwrite(output_img, img0)
    return window_data, output_img

def extract_dimensions_from_pdf():
    """Extract measurements from PDF using regex patterns"""
    doc = fitz.open(PDF_PATH)
    dimensions = {"length": None, "width": None}
    
    # Regex patterns for dimensions (customize based on your PDF format)
    patterns = {
        "length": r"Length:\s*(\d+\.?\d*)\s*[mM]",
        "width": r"Width:\s*(\d+\.?\d*)\s*[mM]"
    }
    
    for page in doc:
        text = page.get_text()
        for key, pattern in patterns.items():
            match = re.search(pattern, text)
            if match and not dimensions[key]:
                dimensions[key] = float(match.group(1))
    
    return dimensions

def main():
    setup_environment()
    
    # Run window detection
    window_data, output_img = detect_windows()
    print("\nWindow Detection Results:")
    for i, window in enumerate(window_data, 1):
        print(f"Window {i}:")
        print(f"  Bounding Box: {window['bbox']}")
        print(f"  Confidence: {window['confidence']:.2f}")
        print(f"  Class ID: {window['class']}")
    
    # Extract PDF dimensions
    dimensions = extract_dimensions_from_pdf()
    print("\nPDF Dimension Extraction:")
    print(f"Length: {dimensions['length']}m" if dimensions['length'] else "Length not found")
    print(f"Width: {dimensions['width']}m" if dimensions['width'] else "Width not found")
    
    print(f"\nDetection image saved to: {output_img}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 126
#     123     print(f"\nDetection image saved to: {output_img}")
#     125 if __name__ == "__main__":
# --> 126     main()
#
# Cell In[6], line 109, in main()
#     106 setup_environment()
#     108 # Run window detection
# --> 109 window_data, output_img = detect_windows()
#     110 print("\nWindow Detection Results:")
#     111 for i, window in enumerate(window_data, 1):
#
# Cell In[6], line 45, in detect_windows()
#      43 """Run YOLOv5 window detection on the target image"""
#      44 from models.experimental import attempt_load
# ---> 45 from utils.general import non_max_suppression, scale_coords, letterbox
#      47 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      48 model = attempt_load(MODEL_PATH, device=device)
#
# ...
