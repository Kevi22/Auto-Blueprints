# %% [markdown]
# # Object detection with SESYD

# %% [markdown]
# ## Dataset

# %%
import kagglehub
import torch
import torchvision
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader
import os
from PIL import Image
import numpy as np

# Download latest version
def load_sesyd_dataset():
    path = kagglehub.dataset_download("vanhaole/sesyd-dataset")
    return path

# %%
# EDA

# %%
class SESYDDataset(Dataset):
    def __init__(self, path, transform=None):
        self.path = path
        self.transform = transform
        self.images = [f for f in os.listdir(os.path.join(path, 'images'))
                       if f.endswith(('.jpg', '.png'))]

# %%
import json
import requests
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'using {device} for inference')
# Out:
# using cpu for inference

# %% [markdown]
# ## Model

# %%
resneXt = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_resneXt')
utils = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_convnets_processing_utils')

resneXt.eval().to(device)
# Out:
# Using cache found in C:\Users\MaxF�rsntr�m-AI23GBG/.cache\torch\hub\NVIDIA_DeepLearningExamples_torchhub
# Using cache found in C:\Users\MaxF�rsntr�m-AI23GBG/.cache\torch\hub\NVIDIA_DeepLearningExamples_torchhub
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layers): Sequential(
#     (0): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Preprocessing Images
